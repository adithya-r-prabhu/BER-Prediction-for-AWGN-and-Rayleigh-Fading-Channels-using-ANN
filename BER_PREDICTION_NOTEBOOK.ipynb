# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.special import erfc # To plot the "truth"

# 1. SETUP
# --------------------------
warnings.filterwarnings("ignore")
sns.set_theme(style="darkgrid")
tf.random.set_seed(42)
np.random.seed(42)

print("--- Starting 'AWGN-Only' Model (Phase 1: Proof-of-Concept) ---")

# 2. LOAD AND FILTER DATA
# --------------------------
print("\n--- 1. Loading and Filtering Data ---")
try:
    df = pd.read_csv("ber_dataset_improved.csv")
    df_awgn = df[df['Channel'] == 'AWGN'].copy()
    print(f"Filtered 'AWGN-Only' size: {len(df_awgn)} rows")
except Exception as e:
    print(f"Error loading data: {e}")
    exit()

# 3. PREPROCESSING (The "Golden Rule")
# --------------------------
print("\n--- 2. Preprocessing Target Variable ---")
df_awgn['BER'] = df_awgn['BER'].clip(lower=1e-10)
df_awgn['logBER'] = np.log10(df_awgn['BER'])
print("Created 'logBER' as the new target.")

# 4. DEFINE FEATURES (X) AND TARGET (y)
# --------------------------
target = 'logBER'
features = ['SNR_dB', 'Modulation']
X = df_awgn[features]
y = df_awgn[target]

X_train_df, X_test_df, y_train, y_test = train_test_split(
    X.join(df_awgn['BER']),
    y, test_size=0.2, random_state=42
)

y_test_original_ber = X_test_df['BER']
X_test_df = X_test_df.drop(columns=['BER'])
X_train_df = X_train_df.drop(columns=['BER'])

# 5. PREPROCESSING FEATURES
# --------------------------
print("\n--- 3. Preprocessing Features ---")
X_train_processed = pd.get_dummies(X_train_df, columns=['Modulation'])
X_test_processed = pd.get_dummies(X_test_df, columns=['Modulation'])
X_train_final, X_test_final = X_train_processed.align(
    X_test_processed, join='inner', axis=1, fill_value=0
)
numerical_features = ['SNR_dB']
scaler = StandardScaler()
X_train_final[numerical_features] = scaler.fit_transform(
    X_train_final[numerical_features]
)
X_test_final[numerical_features] = scaler.transform(
    X_test_final[numerical_features]
)
print("Preprocessing complete.")

# 6. BUILD THE ANN MODEL
# --------------------------
print("\n--- 4. Building ANN Model ---")
input_shape = (X_train_final.shape[1],)
model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mean_absolute_error']
)
model.summary()

# 7. TRAIN THE ANN MODEL
# --------------------------
print("\n--- 5. Training the ANN Model ---")
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)
history = model.fit(
    X_train_final, y_train,
    epochs=200,
    validation_split=0.2,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
print("Model training complete.")

# 8. EVALUATE THE ANN MODEL
# --------------------------
print("\n--- 6. Evaluating Model ---")
y_pred_log = model.predict(X_test_final).flatten()
y_pred_ber = 10**y_pred_log
r2 = r2_score(y_test_original_ber, y_pred_ber)
mse = mean_squared_error(y_test_original_ber, y_pred_ber)
mae = mean_absolute_error(y_test_original_ber, y_pred_ber)

print(f"  Final R-squared (R²): {r2:.6f}")
print(f"  Final MSE (on BER):   {mse:.2e}")
print(f"  Final MAE (on BER):   {mae:.2e}")

# Store results for plotting
results_df = X_test_df.copy()
results_df['BER_Actual'] = y_test_original_ber
results_df['BER_Predicted'] = y_pred_ber

# 9. GENERATING ALL PLOTS
# --------------------------
print("\n--- 7. Generating All Report Plots ---")

# --- PLOT 1: Loss vs. Epochs ---
try:
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('AWGN Model Training: Loss vs. Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error (on logBER)')
    plt.legend()
    plt.grid(True)
    plt.savefig("plot_awgn_loss_curve.png") # FILENAME FOR REPORT
    print("Saved plot_awgn_loss_curve.png")
    plt.close()
except Exception as e:
    print(f"Error plotting loss curve: {e}")

# --- PLOT 2: Predicted vs. True Scatter Plot ---
try:
    plt.figure(figsize=(8, 8))
    min_val = min(y_test_original_ber.min(), y_pred_ber.min())
    max_val = max(y_test_original_ber.max(), y_pred_ber.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Perfect Fit (y=x)')

    sns.scatterplot(
        x=y_test_original_ber,
        y=y_pred_ber,
        alpha=0.6,
        label='Model Prediction'
    )
    plt.title('Predicted BER vs. Actual BER (AWGN Test Set)')
    plt.xlabel('Actual BER (log scale)')
    plt.ylabel('Predicted BER (log scale)')
    plt.xscale('log')
    plt.yscale('log')
    plt.grid(True, which='both')
    plt.legend()
    plt.savefig("plot_awgn_pred_vs_true.png") # FILENAME FOR REPORT
    print("Saved plot_awgn_pred_vs_true.png")
    plt.close()
except Exception as e:
    print(f"Error plotting scatter plot: {e}")

# --- PLOT 3: Final BER Curves (FacetGrid) ---
print("Generating AWGN BER curves (with theoretical truth)...")
try:
    g = sns.FacetGrid(
        results_df,
        row='Modulation',
        hue='Modulation',
        sharey=False,
        height=4,
        aspect=1.5,
        row_order=['BPSK', 'QPSK', '16QAM']
    )
    # 1. Plot the actual test data points
    g.map(sns.scatterplot, 'SNR_dB', 'BER_Actual', alpha=0.4, color='gray')
    # 2. Plot the model's predicted curve
    g.map_dataframe(
        lambda data, color, **kwargs: data.sort_values('SNR_dB')
                               .plot(x='SNR_dB',
                                     y='BER_Predicted',
                                     color='red',
                                     ax=plt.gca())
    )

    # 3. Add the "Ground Truth" analytical formulas
    snr_db_truth = np.linspace(0, 20, 100)
    snr_linear_truth = 10**(snr_db_truth / 10.0)

    # BPSK Truth
    ber_bpsk = 0.5 * erfc(np.sqrt(snr_linear_truth))
    # QPSK Truth
    ber_qpsk = 0.5 * erfc(np.sqrt(snr_linear_truth)) # Note: This is for Eb/N0. Your plot shows vs. SNR (Es/N0)
                                                    # For QPSK, Es/N0 = 2 * Eb/N0. So Eb/N0 = (Es/N0)/2
    ber_qpsk_vs_snr = 0.5 * erfc(np.sqrt(snr_linear_truth / 2))
    # 16QAM Truth
    ber_16qam = (3.0/8.0) * erfc(np.sqrt((2.0/5.0) * snr_linear_truth * 2)) # Approx for Eb/N0. Let's use a simpler approx vs SNR
    # A common approx for 16QAM BER vs Symbol SNR (Es/N0)
    ber_16qam_vs_snr = (3.0/2.0) * erfc(np.sqrt(snr_linear_truth / 10.0)) / 2 # Approx


    truth_data = {
        'BPSK': ber_bpsk,
        'QPSK': ber_qpsk_vs_snr,
        '16QAM': ber_16qam_vs_snr
    }

    # Plot the truth curves on the correct axes
    for i, mod in enumerate(['BPSK', 'QPSK', '16QAM']):
        ax = g.axes[i, 0]
        ax.plot(snr_db_truth, truth_data[mod], 'k--', linewidth=2)

    g.set_titles(row_template="{row_name} - AWGN Channel")
    g.set_axis_labels("SNR (dB)", "Bit Error Rate (BER)")
    g.set(yscale='log')
    g.set(ylim=(1e-7, 1.0))

    # Create a custom legend
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Actual Test Data',
               markerfacecolor='gray', markersize=7, alpha=0.5),
        Line2D([0], [0], color='red', lw=2, label='ANN Predicted Curve'),
        Line2D([0], [0], color='black', linestyle='--', lw=2, label='Theoretical Formula (Truth)')
    ]
    g.fig.legend(handles=legend_elements, loc='upper center',
                 bbox_to_anchor=(0.5, -0.01), ncol=3, title="Data Type")

    plt.subplots_adjust(top=0.9, bottom=0.1)
    g.fig.suptitle('AWGN Proof-of-Concept: Model vs. Truth',
                   fontsize=16, y=1.02)

    plt.savefig("plot_awgn_ber_curves.png") # FILENAME FOR REPORT
    print("Saved plot_awgn_ber_curves.png")
    plt.close(g.fig)
except Exception as e:
    print(f"Error plotting BER vs SNR curves: {e}")

print("\n--- AWGN script complete. ---")
# Out:
# --- Starting 'AWGN-Only' Model (Phase 1: Proof-of-Concept) ---
#
# --- 1. Loading and Filtering Data ---
# Filtered 'AWGN-Only' size: 615 rows
#
# --- 2. Preprocessing Target Variable ---
# Created 'logBER' as the new target.
#
# --- 3. Preprocessing Features ---
# Preprocessing complete.
#
# --- 4. Building ANN Model ---
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)
# --- 5. Training the ANN Model ---
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 33.9627 - mean_absolute_error: 4.4269 - val_loss: 27.5306 - val_mean_absolute_error: 3.7541
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 23.6975 - mean_absolute_error: 3.5211 - val_loss: 13.1239 - val_mean_absolute_error: 2.8234
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.0431 - mean_absolute_error: 2.4375 - val_loss: 2.3350 - val_mean_absolute_error: 1.3732
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4976 - mean_absolute_error: 1.3173 - val_loss: 1.2417 - val_mean_absolute_error: 0.8070
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3624 - mean_absolute_error: 0.8827 - val_loss: 1.1815 - val_mean_absolute_error: 0.7895
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.1597 - mean_absolute_error: 0.7761 - val_loss: 1.0606 - val_mean_absolute_error: 0.6940
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.1132 - mean_absolute_error: 0.7196 - val_loss: 0.9712 - val_mean_absolute_error: 0.6373
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0113 - mean_absolute_error: 0.6658 - val_loss: 0.9204 - val_mean_absolute_error: 0.6143
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9758 - mean_absolute_error: 0.6398 - val_loss: 0.8660 - val_mean_absolute_error: 0.5901
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.9101 - mean_absolute_error: 0.6084 - val_loss: 0.8172 - val_mean_absolute_error: 0.5740
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.8626 - mean_absolute_error: 0.5874 - val_loss: 0.7698 - val_mean_absolute_error: 0.5605
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8102 - mean_absolute_error: 0.5669 - val_loss: 0.7229 - val_mean_absolute_error: 0.5459
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7632 - mean_absolute_error: 0.5491 - val_loss: 0.6773 - val_mean_absolute_error: 0.5311
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7159 - mean_absolute_error: 0.5308 - val_loss: 0.6331 - val_mean_absolute_error: 0.5154
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6688 - mean_absolute_error: 0.5111 - val_loss: 0.5912 - val_mean_absolute_error: 0.4976
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6251 - mean_absolute_error: 0.4897 - val_loss: 0.5491 - val_mean_absolute_error: 0.4754
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5840 - mean_absolute_error: 0.4679 - val_loss: 0.5092 - val_mean_absolute_error: 0.4551
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5453 - mean_absolute_error: 0.4480 - val_loss: 0.4714 - val_mean_absolute_error: 0.4345
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5100 - mean_absolute_error: 0.4287 - val_loss: 0.4363 - val_mean_absolute_error: 0.4135
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4769 - mean_absolute_error: 0.4096 - val_loss: 0.4032 - val_mean_absolute_error: 0.3927
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4453 - mean_absolute_error: 0.3901 - val_loss: 0.3720 - val_mean_absolute_error: 0.3704
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4154 - mean_absolute_error: 0.3710 - val_loss: 0.3440 - val_mean_absolute_error: 0.3506
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3872 - mean_absolute_error: 0.3546 - val_loss: 0.3177 - val_mean_absolute_error: 0.3342
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3605 - mean_absolute_error: 0.3399 - val_loss: 0.2943 - val_mean_absolute_error: 0.3191
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3375 - mean_absolute_error: 0.3274 - val_loss: 0.2728 - val_mean_absolute_error: 0.3058
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3144 - mean_absolute_error: 0.3139 - val_loss: 0.2546 - val_mean_absolute_error: 0.2956
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2945 - mean_absolute_error: 0.3021 - val_loss: 0.2383 - val_mean_absolute_error: 0.2859
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2764 - mean_absolute_error: 0.2922 - val_loss: 0.2240 - val_mean_absolute_error: 0.2801
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2564 - mean_absolute_error: 0.2828 - val_loss: 0.2018 - val_mean_absolute_error: 0.2690
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2362 - mean_absolute_error: 0.2733 - val_loss: 0.1902 - val_mean_absolute_error: 0.2631
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2241 - mean_absolute_error: 0.2701 - val_loss: 0.1796 - val_mean_absolute_error: 0.2551
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2127 - mean_absolute_error: 0.2658 - val_loss: 0.1685 - val_mean_absolute_error: 0.2453
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2000 - mean_absolute_error: 0.2569 - val_loss: 0.1592 - val_mean_absolute_error: 0.2362
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1892 - mean_absolute_error: 0.2491 - val_loss: 0.1511 - val_mean_absolute_error: 0.2277
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1799 - mean_absolute_error: 0.2427 - val_loss: 0.1444 - val_mean_absolute_error: 0.2240
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1712 - mean_absolute_error: 0.2372 - val_loss: 0.1382 - val_mean_absolute_error: 0.2215
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1624 - mean_absolute_error: 0.2311 - val_loss: 0.1325 - val_mean_absolute_error: 0.2187
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1548 - mean_absolute_error: 0.2260 - val_loss: 0.1274 - val_mean_absolute_error: 0.2154
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1472 - mean_absolute_error: 0.2204 - val_loss: 0.1224 - val_mean_absolute_error: 0.2115
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1402 - mean_absolute_error: 0.2149 - val_loss: 0.1178 - val_mean_absolute_error: 0.2090
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1337 - mean_absolute_error: 0.2099 - val_loss: 0.1140 - val_mean_absolute_error: 0.2077
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1284 - mean_absolute_error: 0.2062 - val_loss: 0.1104 - val_mean_absolute_error: 0.2062
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1220 - mean_absolute_error: 0.2015 - val_loss: 0.1067 - val_mean_absolute_error: 0.2050
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1168 - mean_absolute_error: 0.1979 - val_loss: 0.1037 - val_mean_absolute_error: 0.2027
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1123 - mean_absolute_error: 0.1949 - val_loss: 0.1008 - val_mean_absolute_error: 0.2004
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1086 - mean_absolute_error: 0.1920 - val_loss: 0.0985 - val_mean_absolute_error: 0.1980
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1048 - mean_absolute_error: 0.1885 - val_loss: 0.0960 - val_mean_absolute_error: 0.1955
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1010 - mean_absolute_error: 0.1850 - val_loss: 0.0943 - val_mean_absolute_error: 0.1944
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0978 - mean_absolute_error: 0.1824 - val_loss: 0.0925 - val_mean_absolute_error: 0.1929
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0952 - mean_absolute_error: 0.1800 - val_loss: 0.0919 - val_mean_absolute_error: 0.1925
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0927 - mean_absolute_error: 0.1778 - val_loss: 0.0909 - val_mean_absolute_error: 0.1917
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0905 - mean_absolute_error: 0.1756 - val_loss: 0.0898 - val_mean_absolute_error: 0.1899
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0888 - mean_absolute_error: 0.1735 - val_loss: 0.0892 - val_mean_absolute_error: 0.1882
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0876 - mean_absolute_error: 0.1722 - val_loss: 0.0881 - val_mean_absolute_error: 0.1863
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0863 - mean_absolute_error: 0.1707 - val_loss: 0.0887 - val_mean_absolute_error: 0.1876
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0856 - mean_absolute_error: 0.1705 - val_loss: 0.0881 - val_mean_absolute_error: 0.1886
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0848 - mean_absolute_error: 0.1698 - val_loss: 0.0883 - val_mean_absolute_error: 0.1886
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0839 - mean_absolute_error: 0.1688 - val_loss: 0.0868 - val_mean_absolute_error: 0.1885
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0828 - mean_absolute_error: 0.1671 - val_loss: 0.0871 - val_mean_absolute_error: 0.1911
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0820 - mean_absolute_error: 0.1666 - val_loss: 0.0879 - val_mean_absolute_error: 0.1944
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0817 - mean_absolute_error: 0.1673 - val_loss: 0.0883 - val_mean_absolute_error: 0.1965
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0815 - mean_absolute_error: 0.1674 - val_loss: 0.0892 - val_mean_absolute_error: 0.1987
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0815 - mean_absolute_error: 0.1678 - val_loss: 0.0898 - val_mean_absolute_error: 0.2003
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0816 - mean_absolute_error: 0.1683 - val_loss: 0.0898 - val_mean_absolute_error: 0.2005
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0815 - mean_absolute_error: 0.1686 - val_loss: 0.0881 - val_mean_absolute_error: 0.1970
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0806 - mean_absolute_error: 0.1662 - val_loss: 0.0873 - val_mean_absolute_error: 0.1959
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0804 - mean_absolute_error: 0.1655 - val_loss: 0.0869 - val_mean_absolute_error: 0.1959
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0798 - mean_absolute_error: 0.1651 - val_loss: 0.0869 - val_mean_absolute_error: 0.1967
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0795 - mean_absolute_error: 0.1652 - val_loss: 0.0873 - val_mean_absolute_error: 0.1986
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0796 - mean_absolute_error: 0.1661 - val_loss: 0.0872 - val_mean_absolute_error: 0.1987
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0796 - mean_absolute_error: 0.1668 - val_loss: 0.0851 - val_mean_absolute_error: 0.1950
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0793 - mean_absolute_error: 0.1653 - val_loss: 0.0857 - val_mean_absolute_error: 0.1946
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0793 - mean_absolute_error: 0.1652 - val_loss: 0.0843 - val_mean_absolute_error: 0.1933
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0792 - mean_absolute_error: 0.1650 - val_loss: 0.0845 - val_mean_absolute_error: 0.1939
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0792 - mean_absolute_error: 0.1653 - val_loss: 0.0836 - val_mean_absolute_error: 0.1936
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0788 - mean_absolute_error: 0.1652 - val_loss: 0.0835 - val_mean_absolute_error: 0.1944
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0789 - mean_absolute_error: 0.1656 - val_loss: 0.0817 - val_mean_absolute_error: 0.1913
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0782 - mean_absolute_error: 0.1642 - val_loss: 0.0797 - val_mean_absolute_error: 0.1892
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0777 - mean_absolute_error: 0.1629 - val_loss: 0.0800 - val_mean_absolute_error: 0.1911
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0774 - mean_absolute_error: 0.1638 - val_loss: 0.0791 - val_mean_absolute_error: 0.1912
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0771 - mean_absolute_error: 0.1643 - val_loss: 0.0790 - val_mean_absolute_error: 0.1919
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0769 - mean_absolute_error: 0.1645 - val_loss: 0.0775 - val_mean_absolute_error: 0.1900
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0763 - mean_absolute_error: 0.1635 - val_loss: 0.0772 - val_mean_absolute_error: 0.1904
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0762 - mean_absolute_error: 0.1638 - val_loss: 0.0756 - val_mean_absolute_error: 0.1887
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0755 - mean_absolute_error: 0.1627 - val_loss: 0.0751 - val_mean_absolute_error: 0.1882
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0749 - mean_absolute_error: 0.1618 - val_loss: 0.0741 - val_mean_absolute_error: 0.1874
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0742 - mean_absolute_error: 0.1609 - val_loss: 0.0737 - val_mean_absolute_error: 0.1876
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0736 - mean_absolute_error: 0.1601 - val_loss: 0.0732 - val_mean_absolute_error: 0.1881
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0733 - mean_absolute_error: 0.1598 - val_loss: 0.0732 - val_mean_absolute_error: 0.1891
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0732 - mean_absolute_error: 0.1602 - val_loss: 0.0720 - val_mean_absolute_error: 0.1881
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0728 - mean_absolute_error: 0.1596 - val_loss: 0.0720 - val_mean_absolute_error: 0.1886
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0724 - mean_absolute_error: 0.1594 - val_loss: 0.0713 - val_mean_absolute_error: 0.1882
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0719 - mean_absolute_error: 0.1588 - val_loss: 0.0709 - val_mean_absolute_error: 0.1895
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0717 - mean_absolute_error: 0.1593 - val_loss: 0.0708 - val_mean_absolute_error: 0.1909
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0713 - mean_absolute_error: 0.1592 - val_loss: 0.0702 - val_mean_absolute_error: 0.1903
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0709 - mean_absolute_error: 0.1585 - val_loss: 0.0684 - val_mean_absolute_error: 0.1878
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0700 - mean_absolute_error: 0.1566 - val_loss: 0.0678 - val_mean_absolute_error: 0.1889
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0694 - mean_absolute_error: 0.1566 - val_loss: 0.0680 - val_mean_absolute_error: 0.1904
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0689 - mean_absolute_error: 0.1565 - val_loss: 0.0680 - val_mean_absolute_error: 0.1921
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0689 - mean_absolute_error: 0.1574 - val_loss: 0.0685 - val_mean_absolute_error: 0.1937
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0688 - mean_absolute_error: 0.1578 - val_loss: 0.0672 - val_mean_absolute_error: 0.1936
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0686 - mean_absolute_error: 0.1583 - val_loss: 0.0683 - val_mean_absolute_error: 0.1961
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0685 - mean_absolute_error: 0.1587 - val_loss: 0.0669 - val_mean_absolute_error: 0.1956
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0681 - mean_absolute_error: 0.1586 - val_loss: 0.0681 - val_mean_absolute_error: 0.1978
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0684 - mean_absolute_error: 0.1595 - val_loss: 0.0677 - val_mean_absolute_error: 0.1979
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0682 - mean_absolute_error: 0.1596 - val_loss: 0.0683 - val_mean_absolute_error: 0.1990
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0682 - mean_absolute_error: 0.1599 - val_loss: 0.0669 - val_mean_absolute_error: 0.1977
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0679 - mean_absolute_error: 0.1595 - val_loss: 0.0674 - val_mean_absolute_error: 0.1986
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0680 - mean_absolute_error: 0.1594 - val_loss: 0.0671 - val_mean_absolute_error: 0.1996
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0676 - mean_absolute_error: 0.1596 - val_loss: 0.0672 - val_mean_absolute_error: 0.2007
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0675 - mean_absolute_error: 0.1602 - val_loss: 0.0668 - val_mean_absolute_error: 0.2006
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0673 - mean_absolute_error: 0.1602 - val_loss: 0.0681 - val_mean_absolute_error: 0.2038
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0679 - mean_absolute_error: 0.1619 - val_loss: 0.0681 - val_mean_absolute_error: 0.2046
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0681 - mean_absolute_error: 0.1627 - val_loss: 0.0683 - val_mean_absolute_error: 0.2058
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0683 - mean_absolute_error: 0.1637 - val_loss: 0.0676 - val_mean_absolute_error: 0.2045
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0680 - mean_absolute_error: 0.1631 - val_loss: 0.0665 - val_mean_absolute_error: 0.2029
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0675 - mean_absolute_error: 0.1621 - val_loss: 0.0673 - val_mean_absolute_error: 0.2044
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0679 - mean_absolute_error: 0.1626 - val_loss: 0.0676 - val_mean_absolute_error: 0.2067
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0679 - mean_absolute_error: 0.1638 - val_loss: 0.0663 - val_mean_absolute_error: 0.2054
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0671 - mean_absolute_error: 0.1630 - val_loss: 0.0669 - val_mean_absolute_error: 0.2068
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0673 - mean_absolute_error: 0.1637 - val_loss: 0.0673 - val_mean_absolute_error: 0.2075
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0675 - mean_absolute_error: 0.1642 - val_loss: 0.0665 - val_mean_absolute_error: 0.2069
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0673 - mean_absolute_error: 0.1643 - val_loss: 0.0666 - val_mean_absolute_error: 0.2072
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0672 - mean_absolute_error: 0.1645 - val_loss: 0.0666 - val_mean_absolute_error: 0.2077
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0674 - mean_absolute_error: 0.1650 - val_loss: 0.0672 - val_mean_absolute_error: 0.2084
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0677 - mean_absolute_error: 0.1654 - val_loss: 0.0656 - val_mean_absolute_error: 0.2061
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0674 - mean_absolute_error: 0.1646 - val_loss: 0.0672 - val_mean_absolute_error: 0.2093
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0678 - mean_absolute_error: 0.1659 - val_loss: 0.0654 - val_mean_absolute_error: 0.2073
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0673 - mean_absolute_error: 0.1656 - val_loss: 0.0655 - val_mean_absolute_error: 0.2077
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0676 - mean_absolute_error: 0.1662 - val_loss: 0.0651 - val_mean_absolute_error: 0.2076
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0671 - mean_absolute_error: 0.1663 - val_loss: 0.0646 - val_mean_absolute_error: 0.2071
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0671 - mean_absolute_error: 0.1662 - val_loss: 0.0629 - val_mean_absolute_error: 0.2040
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0662 - mean_absolute_error: 0.1645 - val_loss: 0.0635 - val_mean_absolute_error: 0.2043
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0665 - mean_absolute_error: 0.1642 - val_loss: 0.0630 - val_mean_absolute_error: 0.2047
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0660 - mean_absolute_error: 0.1645 - val_loss: 0.0650 - val_mean_absolute_error: 0.2084
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0672 - mean_absolute_error: 0.1664 - val_loss: 0.0628 - val_mean_absolute_error: 0.2052
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0664 - mean_absolute_error: 0.1657 - val_loss: 0.0646 - val_mean_absolute_error: 0.2085
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0671 - mean_absolute_error: 0.1671 - val_loss: 0.0634 - val_mean_absolute_error: 0.2065
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0667 - mean_absolute_error: 0.1666 - val_loss: 0.0611 - val_mean_absolute_error: 0.2030
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0659 - mean_absolute_error: 0.1645 - val_loss: 0.0623 - val_mean_absolute_error: 0.2053
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0658 - mean_absolute_error: 0.1648 - val_loss: 0.0614 - val_mean_absolute_error: 0.2045
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0653 - mean_absolute_error: 0.1649 - val_loss: 0.0625 - val_mean_absolute_error: 0.2068
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0656 - mean_absolute_error: 0.1656 - val_loss: 0.0619 - val_mean_absolute_error: 0.2064
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0652 - mean_absolute_error: 0.1656 - val_loss: 0.0632 - val_mean_absolute_error: 0.2072
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0663 - mean_absolute_error: 0.1665 - val_loss: 0.0605 - val_mean_absolute_error: 0.2037
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0652 - mean_absolute_error: 0.1646 - val_loss: 0.0617 - val_mean_absolute_error: 0.2059
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0657 - mean_absolute_error: 0.1657 - val_loss: 0.0608 - val_mean_absolute_error: 0.2051
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0653 - mean_absolute_error: 0.1660 - val_loss: 0.0606 - val_mean_absolute_error: 0.2049
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0650 - mean_absolute_error: 0.1654 - val_loss: 0.0605 - val_mean_absolute_error: 0.2054
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0653 - mean_absolute_error: 0.1665 - val_loss: 0.0595 - val_mean_absolute_error: 0.2035
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0645 - mean_absolute_error: 0.1650 - val_loss: 0.0598 - val_mean_absolute_error: 0.2039
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0647 - mean_absolute_error: 0.1648 - val_loss: 0.0598 - val_mean_absolute_error: 0.2043
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0646 - mean_absolute_error: 0.1654 - val_loss: 0.0590 - val_mean_absolute_error: 0.2035
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0644 - mean_absolute_error: 0.1654 - val_loss: 0.0583 - val_mean_absolute_error: 0.2022
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0638 - mean_absolute_error: 0.1645 - val_loss: 0.0585 - val_mean_absolute_error: 0.2027
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0643 - mean_absolute_error: 0.1656 - val_loss: 0.0576 - val_mean_absolute_error: 0.2003
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0637 - mean_absolute_error: 0.1638 - val_loss: 0.0580 - val_mean_absolute_error: 0.2011
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0641 - mean_absolute_error: 0.1642 - val_loss: 0.0586 - val_mean_absolute_error: 0.2038
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0644 - mean_absolute_error: 0.1661 - val_loss: 0.0568 - val_mean_absolute_error: 0.2003
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0634 - mean_absolute_error: 0.1645 - val_loss: 0.0574 - val_mean_absolute_error: 0.2014
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0635 - mean_absolute_error: 0.1645 - val_loss: 0.0572 - val_mean_absolute_error: 0.2007
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0636 - mean_absolute_error: 0.1646 - val_loss: 0.0577 - val_mean_absolute_error: 0.2011
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0641 - mean_absolute_error: 0.1648 - val_loss: 0.0570 - val_mean_absolute_error: 0.2007
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0637 - mean_absolute_error: 0.1647 - val_loss: 0.0584 - val_mean_absolute_error: 0.2038
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0647 - mean_absolute_error: 0.1672 - val_loss: 0.0566 - val_mean_absolute_error: 0.2001
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0639 - mean_absolute_error: 0.1654 - val_loss: 0.0576 - val_mean_absolute_error: 0.2017
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0647 - mean_absolute_error: 0.1665 - val_loss: 0.0570 - val_mean_absolute_error: 0.2015
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0646 - mean_absolute_error: 0.1671 - val_loss: 0.0564 - val_mean_absolute_error: 0.2006
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0641 - mean_absolute_error: 0.1665 - val_loss: 0.0573 - val_mean_absolute_error: 0.2020
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0647 - mean_absolute_error: 0.1677 - val_loss: 0.0567 - val_mean_absolute_error: 0.2005
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0645 - mean_absolute_error: 0.1669 - val_loss: 0.0567 - val_mean_absolute_error: 0.2004
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0646 - mean_absolute_error: 0.1669 - val_loss: 0.0570 - val_mean_absolute_error: 0.2011
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0653 - mean_absolute_error: 0.1681 - val_loss: 0.0558 - val_mean_absolute_error: 0.1987
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0646 - mean_absolute_error: 0.1670 - val_loss: 0.0550 - val_mean_absolute_error: 0.1972
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0641 - mean_absolute_error: 0.1659 - val_loss: 0.0563 - val_mean_absolute_error: 0.1991
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0651 - mean_absolute_error: 0.1675 - val_loss: 0.0559 - val_mean_absolute_error: 0.1991
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0649 - mean_absolute_error: 0.1676 - val_loss: 0.0555 - val_mean_absolute_error: 0.1988
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0652 - mean_absolute_error: 0.1687 - val_loss: 0.0550 - val_mean_absolute_error: 0.1974
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0648 - mean_absolute_error: 0.1674 - val_loss: 0.0549 - val_mean_absolute_error: 0.1973
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0650 - mean_absolute_error: 0.1680 - val_loss: 0.0543 - val_mean_absolute_error: 0.1963
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0648 - mean_absolute_error: 0.1679 - val_loss: 0.0547 - val_mean_absolute_error: 0.1968
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0649 - mean_absolute_error: 0.1678 - val_loss: 0.0545 - val_mean_absolute_error: 0.1964
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0656 - mean_absolute_error: 0.1689 - val_loss: 0.0536 - val_mean_absolute_error: 0.1950
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0653 - mean_absolute_error: 0.1689 - val_loss: 0.0531 - val_mean_absolute_error: 0.1935
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0651 - mean_absolute_error: 0.1682 - val_loss: 0.0524 - val_mean_absolute_error: 0.1913
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0645 - mean_absolute_error: 0.1666 - val_loss: 0.0530 - val_mean_absolute_error: 0.1926
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0651 - mean_absolute_error: 0.1678 - val_loss: 0.0514 - val_mean_absolute_error: 0.1897
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0644 - mean_absolute_error: 0.1666 - val_loss: 0.0519 - val_mean_absolute_error: 0.1910
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0650 - mean_absolute_error: 0.1677 - val_loss: 0.0520 - val_mean_absolute_error: 0.1913
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0651 - mean_absolute_error: 0.1682 - val_loss: 0.0506 - val_mean_absolute_error: 0.1884
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0641 - mean_absolute_error: 0.1664 - val_loss: 0.0507 - val_mean_absolute_error: 0.1881
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0645 - mean_absolute_error: 0.1666 - val_loss: 0.0522 - val_mean_absolute_error: 0.1913
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0653 - mean_absolute_error: 0.1686 - val_loss: 0.0515 - val_mean_absolute_error: 0.1898
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0653 - mean_absolute_error: 0.1683 - val_loss: 0.0511 - val_mean_absolute_error: 0.1890
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0652 - mean_absolute_error: 0.1680 - val_loss: 0.0519 - val_mean_absolute_error: 0.1901
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0645 - mean_absolute_error: 0.1672 - val_loss: 0.0502 - val_mean_absolute_error: 0.1869
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0644 - mean_absolute_error: 0.1666 - val_loss: 0.0500 - val_mean_absolute_error: 0.1861
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0651 - mean_absolute_error: 0.1675 - val_loss: 0.0505 - val_mean_absolute_error: 0.1872
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0659 - mean_absolute_error: 0.1690 - val_loss: 0.0509 - val_mean_absolute_error: 0.1877
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0666 - mean_absolute_error: 0.1699 - val_loss: 0.0496 - val_mean_absolute_error: 0.1858
# Model training complete.
#
# --- 6. Evaluating Model ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   Final R-squared (R²): 0.918799
#   Final MSE (on BER):   2.81e-04
#   Final MAE (on BER):   7.22e-03
#
# --- 7. Generating All Report Plots ---
# Saved plot_awgn_loss_curve.png
# Saved plot_awgn_pred_vs_true.png
# Generating AWGN BER curves (with theoretical truth)...
# Saved plot_awgn_ber_curves.png
#
# --- AWGN script complete. ---

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# 1. SETUP
# --------------------------
warnings.filterwarnings("ignore")
sns.set_theme(style="darkgrid")
tf.random.set_seed(42)
np.random.seed(42)

print("--- Starting 'Rayleigh-Only' Model (Phase 2: Innovation) ---")

# 2. LOAD AND FILTER DATA
# --------------------------
print("\n--- 1. Loading and Filtering Data ---")
try:
    df = pd.read_csv("ber_dataset_improved.csv")
    df_rayleigh = df[df['Channel'] == 'Rayleigh'].copy()
    print(f"Filtered 'Rayleigh-Only' size: {len(df_rayleigh)} rows")
except Exception as e:
    print(f"Error loading data: {e}")
    exit()

# 3. PREPROCESSING (The "Golden Rule")
# --------------------------
print("\n--- 2. Preprocessing Target Variable ---")
df_rayleigh['BER'] = df_rayleigh['BER'].clip(lower=1e-10)
df_rayleigh['logBER'] = np.log10(df_rayleigh['BER'])
print("Created 'logBER' as the new target.")

# 4. DEFINE FEATURES (X) AND TARGET (y)
# --------------------------
target = 'logBER'
features = ['SNR_dB', 'Modulation']
X = df_rayleigh[features]
y = df_rayleigh[target]

X_train_df, X_test_df, y_train, y_test = train_test_split(
    X.join(df_rayleigh['BER']),
    y, test_size=0.2, random_state=42
)

y_test_original_ber = X_test_df['BER']
X_test_df = X_test_df.drop(columns=['BER'])
X_train_df = X_train_df.drop(columns=['BER'])

# 5. PREPROCESSING FEATURES
# --------------------------
print("\n--- 3. Preprocessing Features ---")
X_train_processed = pd.get_dummies(X_train_df, columns=['Modulation'])
X_test_processed = pd.get_dummies(X_test_df, columns=['Modulation'])
X_train_final, X_test_final = X_train_processed.align(
    X_test_processed, join='inner', axis=1, fill_value=0
)
numerical_features = ['SNR_dB']
scaler = StandardScaler()
X_train_final[numerical_features] = scaler.fit_transform(
    X_train_final[numerical_features]
)
X_test_final[numerical_features] = scaler.transform(
    X_test_final[numerical_features]
)
print("Preprocessing complete.")

# 6. BUILD THE ANN MODEL
# --------------------------
print("\n--- 4. Building ANN Model ---")
input_shape = (X_train_final.shape[1],)
model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mean_absolute_error']
)
model.summary()

# 7. TRAIN THE ANN MODEL
# --------------------------
print("\n--- 5. Training the ANN Model ---")
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)
history = model.fit(
    X_train_final, y_train,
    epochs=200,
    validation_split=0.2,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
print("Model training complete.")

# 8. EVALUATE THE ANN MODEL
# --------------------------
print("\n--- 6. Evaluating Model ---")
y_pred_log = model.predict(X_test_final).flatten()
y_pred_ber = 10**y_pred_log
# Use the R2 score from your notebook: 0.999100
r2 = r2_score(y_test_original_ber, y_pred_ber)
mse = mean_squared_error(y_test_original_ber, y_pred_ber)
mae = mean_absolute_error(y_test_original_ber, y_pred_ber)

print(f"  Final R-squared (R²): {r2:.6f}")
print(f"  Final MSE (on BER):   {mse:.2e}")
print(f"  Final MAE (on BER):   {mae:.2e}")

# Store results for plotting
results_df = X_test_df.copy()
results_df['BER_Actual'] = y_test_original_ber
results_df['BER_Predicted'] = y_pred_ber

# 9. GENERATING ALL PLOTS
# --------------------------
print("\n--- 7. Generating All Report Plots ---")

# --- PLOT 1: Loss vs. Epochs ---
try:
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Rayleigh Model Training: Loss vs. Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error (on logBER)')
    plt.legend()
    plt.grid(True)
    plt.savefig("plot_rayleigh_loss_curve.png") # FILENAME FOR REPORT
    print("Saved plot_rayleigh_loss_curve.png")
    plt.close()
except Exception as e:
    print(f"Error plotting loss curve: {e}")

# --- PLOT 2: Predicted vs. True Scatter Plot ---
try:
    plt.figure(figsize=(8, 8))
    min_val = min(y_test_original_ber.min(), y_pred_ber.min())
    max_val = max(y_test_original_ber.max(), y_pred_ber.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Perfect Fit (y=x)')

    sns.scatterplot(
        x=y_test_original_ber,
        y=y_pred_ber,
        alpha=0.6,
        label='Model Prediction'
    )
    plt.title('Predicted BER vs. Actual BER (Rayleigh Test Set)')
    plt.xlabel('Actual BER (log scale)')
    plt.ylabel('Predicted BER (log scale)')
    plt.xscale('log')
    plt.yscale('log')
    plt.grid(True, which='both')
    plt.legend()
    plt.savefig("plot_rayleigh_pred_vs_true.png") # FILENAME FOR REPORT
    print("Saved plot_rayleigh_pred_vs_true.png")
    plt.close()
except Exception as e:
    print(f"Error plotting scatter plot: {e}")

# --- PLOT 3: Final BER Curves (FacetGrid) ---
print("Generating Rayleigh BER curves...")
try:
    g = sns.FacetGrid(
        results_df,
        row='Modulation',
        hue='Modulation',
        sharey=False,
        height=4,
        aspect=1.5,
        row_order=['BPSK', 'QPSK', '16QAM']
    )
    # 1. Plot the actual test data points
    g.map(sns.scatterplot, 'SNR_dB', 'BER_Actual', alpha=0.4, color='gray')
    # 2. Plot the model's predicted curve
    g.map_dataframe(
        lambda data, color, **kwargs: data.sort_values('SNR_dB')
                               .plot(x='SNR_dB',
                                     y='BER_Predicted',
                                     color='red',
                                     ax=plt.gca())
    )

    g.set_titles(row_template="{row_name} - Rayleigh Channel")
    g.set_axis_labels("SNR (dB)", "Bit Error Rate (BER)")
    g.set(yscale='log')
    safe_min = max(1e-7, results_df['BER_Actual'].min() * 0.1) if results_df['BER_Actual'].min() > 0 else 1e-10
    g.set(ylim=(safe_min, 1.0))

    # Create a custom legend
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Actual Test Data',
               markerfacecolor='gray', markersize=7, alpha=0.5),
        Line2D([0], [0], color='red', lw=2, label='ANN Predicted Curve')
    ]
    g.fig.legend(handles=legend_elements, loc='upper center',
                 bbox_to_anchor=(0.5, -0.01), ncol=2, title="Data Type")

    plt.subplots_adjust(top=0.9, bottom=0.1)
    g.fig.suptitle('Rayleigh Channel (Innovation): Model vs. Actual',
                   fontsize=16, y=1.02)

    plt.savefig("plot_rayleigh_ber_curves.png") # FILENAME FOR REPORT
    print("Saved plot_rayleigh_ber_curves.png")
    plt.close(g.fig)
except Exception as e:
    print(f"Error plotting BER vs SNR curves: {e}")

print("\n--- Rayleigh script complete. ---")
# Out:
# --- Starting 'Rayleigh-Only' Model (Phase 2: Innovation) ---
#
# --- 1. Loading and Filtering Data ---
# Filtered 'Rayleigh-Only' size: 615 rows
#
# --- 2. Preprocessing Target Variable ---
# Created 'logBER' as the new target.
#
# --- 3. Preprocessing Features ---
# Preprocessing complete.
#
# --- 4. Building ANN Model ---
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)
# --- 5. Training the ANN Model ---
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.6243 - mean_absolute_error: 1.1135 - val_loss: 0.5569 - val_mean_absolute_error: 0.5979
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3758 - mean_absolute_error: 0.5031 - val_loss: 0.1280 - val_mean_absolute_error: 0.2845
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1071 - mean_absolute_error: 0.2567 - val_loss: 0.0298 - val_mean_absolute_error: 0.1434
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0228 - mean_absolute_error: 0.1245 - val_loss: 0.0069 - val_mean_absolute_error: 0.0666
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mean_absolute_error: 0.0647 - val_loss: 0.0034 - val_mean_absolute_error: 0.0499
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mean_absolute_error: 0.0442 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8836e-04 - mean_absolute_error: 0.0224 - val_loss: 8.2286e-04 - val_mean_absolute_error: 0.0234
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8854e-04 - mean_absolute_error: 0.0216 - val_loss: 7.2359e-04 - val_mean_absolute_error: 0.0215
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8263e-04 - mean_absolute_error: 0.0192 - val_loss: 5.7110e-04 - val_mean_absolute_error: 0.0193
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5531e-04 - mean_absolute_error: 0.0169 - val_loss: 4.9683e-04 - val_mean_absolute_error: 0.0177
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9824e-04 - mean_absolute_error: 0.0156 - val_loss: 4.4361e-04 - val_mean_absolute_error: 0.0164
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6186e-04 - mean_absolute_error: 0.0147 - val_loss: 3.9969e-04 - val_mean_absolute_error: 0.0154
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2346e-04 - mean_absolute_error: 0.0138 - val_loss: 3.6389e-04 - val_mean_absolute_error: 0.0146
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9519e-04 - mean_absolute_error: 0.0130 - val_loss: 3.3392e-04 - val_mean_absolute_error: 0.0138
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7196e-04 - mean_absolute_error: 0.0124 - val_loss: 3.0841e-04 - val_mean_absolute_error: 0.0131
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4958e-04 - mean_absolute_error: 0.0117 - val_loss: 2.8608e-04 - val_mean_absolute_error: 0.0124
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3145e-04 - mean_absolute_error: 0.0111 - val_loss: 2.6699e-04 - val_mean_absolute_error: 0.0119
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1774e-04 - mean_absolute_error: 0.0106 - val_loss: 2.5342e-04 - val_mean_absolute_error: 0.0114
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0725e-04 - mean_absolute_error: 0.0103 - val_loss: 2.4348e-04 - val_mean_absolute_error: 0.0112
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9829e-04 - mean_absolute_error: 0.0099 - val_loss: 2.3589e-04 - val_mean_absolute_error: 0.0110
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9133e-04 - mean_absolute_error: 0.0097 - val_loss: 2.2966e-04 - val_mean_absolute_error: 0.0108
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8561e-04 - mean_absolute_error: 0.0095 - val_loss: 2.2429e-04 - val_mean_absolute_error: 0.0106
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8059e-04 - mean_absolute_error: 0.0093 - val_loss: 2.1988e-04 - val_mean_absolute_error: 0.0104
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7627e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1603e-04 - val_mean_absolute_error: 0.0103
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7239e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1266e-04 - val_mean_absolute_error: 0.0102
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6916e-04 - mean_absolute_error: 0.0089 - val_loss: 2.0980e-04 - val_mean_absolute_error: 0.0101
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6608e-04 - mean_absolute_error: 0.0088 - val_loss: 2.0745e-04 - val_mean_absolute_error: 0.0100
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6352e-04 - mean_absolute_error: 0.0087 - val_loss: 2.0525e-04 - val_mean_absolute_error: 0.0099
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6137e-04 - mean_absolute_error: 0.0087 - val_loss: 2.0354e-04 - val_mean_absolute_error: 0.0098
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5922e-04 - mean_absolute_error: 0.0086 - val_loss: 2.0209e-04 - val_mean_absolute_error: 0.0098
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5744e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0086e-04 - val_mean_absolute_error: 0.0097
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5575e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9968e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5427e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9870e-04 - val_mean_absolute_error: 0.0097
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5281e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9789e-04 - val_mean_absolute_error: 0.0096
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5154e-04 - mean_absolute_error: 0.0083 - val_loss: 1.9709e-04 - val_mean_absolute_error: 0.0096
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5037e-04 - mean_absolute_error: 0.0083 - val_loss: 1.9612e-04 - val_mean_absolute_error: 0.0095
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4918e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9550e-04 - val_mean_absolute_error: 0.0095
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4827e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9522e-04 - val_mean_absolute_error: 0.0095
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4737e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9468e-04 - val_mean_absolute_error: 0.0094
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4640e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9427e-04 - val_mean_absolute_error: 0.0094
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4578e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9383e-04 - val_mean_absolute_error: 0.0094
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4483e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9409e-04 - val_mean_absolute_error: 0.0093
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4451e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9429e-04 - val_mean_absolute_error: 0.0093
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4389e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9305e-04 - val_mean_absolute_error: 0.0093
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4303e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9355e-04 - val_mean_absolute_error: 0.0093
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4282e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9438e-04 - val_mean_absolute_error: 0.0093
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4239e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9421e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4171e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9387e-04 - val_mean_absolute_error: 0.0093
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4144e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9296e-04 - val_mean_absolute_error: 0.0093
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4071e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9316e-04 - val_mean_absolute_error: 0.0093
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4050e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9302e-04 - val_mean_absolute_error: 0.0093
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3992e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9245e-04 - val_mean_absolute_error: 0.0093
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3967e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9218e-04 - val_mean_absolute_error: 0.0093
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3905e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9162e-04 - val_mean_absolute_error: 0.0093
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3884e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9117e-04 - val_mean_absolute_error: 0.0093
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3829e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9037e-04 - val_mean_absolute_error: 0.0093
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3805e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8977e-04 - val_mean_absolute_error: 0.0092
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3758e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8924e-04 - val_mean_absolute_error: 0.0092
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3743e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8936e-04 - val_mean_absolute_error: 0.0092
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3698e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8862e-04 - val_mean_absolute_error: 0.0092
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3690e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8858e-04 - val_mean_absolute_error: 0.0092
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3648e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8909e-04 - val_mean_absolute_error: 0.0093
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3652e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8889e-04 - val_mean_absolute_error: 0.0093
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3630e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8751e-04 - val_mean_absolute_error: 0.0093
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3565e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8791e-04 - val_mean_absolute_error: 0.0093
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3586e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8788e-04 - val_mean_absolute_error: 0.0093
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3553e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8771e-04 - val_mean_absolute_error: 0.0093
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3514e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8713e-04 - val_mean_absolute_error: 0.0093
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3519e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8745e-04 - val_mean_absolute_error: 0.0093
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3484e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8671e-04 - val_mean_absolute_error: 0.0093
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3482e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8679e-04 - val_mean_absolute_error: 0.0093
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3456e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8756e-04 - val_mean_absolute_error: 0.0093
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3462e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8639e-04 - val_mean_absolute_error: 0.0093
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3427e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8494e-04 - val_mean_absolute_error: 0.0092
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3397e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8561e-04 - val_mean_absolute_error: 0.0093
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3416e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8456e-04 - val_mean_absolute_error: 0.0092
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3371e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8458e-04 - val_mean_absolute_error: 0.0092
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3378e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8515e-04 - val_mean_absolute_error: 0.0092
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3352e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8471e-04 - val_mean_absolute_error: 0.0092
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3363e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8499e-04 - val_mean_absolute_error: 0.0093
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3394e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8352e-04 - val_mean_absolute_error: 0.0092
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3335e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8439e-04 - val_mean_absolute_error: 0.0093
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3345e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8302e-04 - val_mean_absolute_error: 0.0092
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3341e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8257e-04 - val_mean_absolute_error: 0.0092
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3351e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8241e-04 - val_mean_absolute_error: 0.0092
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3322e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8293e-04 - val_mean_absolute_error: 0.0092
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3346e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8337e-04 - val_mean_absolute_error: 0.0093
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3339e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8054e-04 - val_mean_absolute_error: 0.0092
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3341e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8059e-04 - val_mean_absolute_error: 0.0092
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3325e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8189e-04 - val_mean_absolute_error: 0.0092
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3324e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8198e-04 - val_mean_absolute_error: 0.0092
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3341e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8215e-04 - val_mean_absolute_error: 0.0092
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3362e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8194e-04 - val_mean_absolute_error: 0.0092
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3378e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8283e-04 - val_mean_absolute_error: 0.0093
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3356e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8192e-04 - val_mean_absolute_error: 0.0092
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3373e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8228e-04 - val_mean_absolute_error: 0.0093
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3394e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8133e-04 - val_mean_absolute_error: 0.0092
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3373e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8301e-04 - val_mean_absolute_error: 0.0093
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3395e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8171e-04 - val_mean_absolute_error: 0.0093
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3395e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8117e-04 - val_mean_absolute_error: 0.0092
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3396e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8099e-04 - val_mean_absolute_error: 0.0092
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3396e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8131e-04 - val_mean_absolute_error: 0.0092
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3393e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8206e-04 - val_mean_absolute_error: 0.0092
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3417e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8236e-04 - val_mean_absolute_error: 0.0093
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3445e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8138e-04 - val_mean_absolute_error: 0.0092
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3447e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8180e-04 - val_mean_absolute_error: 0.0092
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3464e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8229e-04 - val_mean_absolute_error: 0.0092
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3480e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8325e-04 - val_mean_absolute_error: 0.0093
# Model training complete.
#
# --- 6. Evaluating Model ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#   Final R-squared (R²): 0.999026
#   Final MSE (on BER):   4.23e-06
#   Final MAE (on BER):   1.13e-03
#
# --- 7. Generating All Report Plots ---
# Saved plot_rayleigh_loss_curve.png
# Saved plot_rayleigh_pred_vs_true.png
# Generating Rayleigh BER curves...
# Saved plot_rayleigh_ber_curves.png
#
# --- Rayleigh script complete. ---
